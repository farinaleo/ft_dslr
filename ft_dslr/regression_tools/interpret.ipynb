# %%
import pandas
import math
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

main_column = 'Hogwarts House'
with open('../setup.json') as f:
    data = json.load(f)
path = data["interpret_path"]
print(f'path : {path}')
pd.set_option('future.no_silent_downcasting', True)
# Out:
# path : /nfs/homes/lfarina/Desktop/ft_dslr/datasets/dataset_train.csv

# %%
def csv_to_dataframe(csv_file: str) -> pandas.DataFrame:
    """Converts a CSV file into a Pandas dataframe"""
    dtf = pandas.read_csv(csv_file)
    return dtf
csv_to_dataframe(path)
# Out:
#       Index Hogwarts House First Name    Last Name    Birthday Best Hand  \
# 0         0      Ravenclaw     Tamara          Hsu  2000-03-30      Left
# 1         1      Slytherin      Erich      Paredes  1999-10-14     Right
# 2         2      Ravenclaw   Stephany        Braun  1999-11-03      Left
# 3         3     Gryffindor      Vesta    Mcmichael  2000-08-19      Left
# 4         4     Gryffindor     Gaston        Gibbs  1998-09-27      Left
# ...     ...            ...        ...          ...         ...       ...
# 1595   1595     Gryffindor       Jung        Blank  2001-09-14     Right
# 1596   1596      Slytherin     Shelli         Lock  1998-03-12      Left
# 1597   1597     Gryffindor   Benjamin  Christensen  1999-10-24     Right
# 1598   1598     Hufflepuff  Charlotte       Dillon  2001-09-21      Left
# 1599   1599     Hufflepuff      Kylie        Nowak  2000-08-21      Left
#
#       Arithmancy   Astronomy  Herbology  Defense Against the Dark Arts  \
# ...

# %%
def scatter_matrix_plot(dtf: pd.DataFrame, house=[['Gryffindor']], figsize=(20,20)):
    """Plot a scatter matrix for each course."""
    if 'Index' in dtf.head():
        dtf = dtf.drop(columns='Index', inplace=False)
    if 'Best Hand' in dtf.head():
        dtf['Best Hand'] = dtf['Best Hand'].replace({'Left': 1, 'Right': 0}).astype(int)
    if 'Birthday' in dtf.columns:
        dtf['Birthday'] = pd.to_datetime(dtf['Birthday'])
        dtf['Month'] = dtf['Birthday'].dt.month
        dtf['Day'] = dtf['Birthday'].dt.day
        dtf['Year'] = dtf['Birthday'].dt.year
        
    nb_features = dtf.select_dtypes(include=['number']).columns.tolist()
    
    # remove the 'Hogwarts House' if it is found in the course list
    if main_column in nb_features:
        nb_features.remove(main_column)

    feature_len = len(nb_features)
    house_len = len(house)
    
    font = {'weight': 'light', 'size': 7}
    plt.rc('font', **font)

    # Set up the matrix (subplot)
    figure, axes = plt.subplots(nrows=house_len, ncols=feature_len, squeeze=False, figsize=figsize, sharex=False, sharey=False)

    # Loop on each course (on x and y) to create the matrix
    for x in range(0, house_len):
        for y in range(0, feature_len):
            # Remove the scatter if a course is compared with itself
            if house[x][0] != nb_features[y]:
                plot_scatter(dtf[[main_column, nb_features[y]]], axes[x, y], house[x], nb_features[y])
            # Add scales only for the first column and the last row
            if x != house_len - 1:
                axes[x, y].tick_params(labelbottom=False)
                axes[x, y].xaxis.set_ticks_position('none')
            else:
                axes[x, y].set_xlabel(nb_features[y].replace(' ', '\n'))
            if y != 0:
                axes[x, y].tick_params(labelleft=False)
                axes[x, y].yaxis.set_ticks_position('none')
            else:
                axes[x, y].set_ylabel(house[x][0])
            if y == feature_len - 1:
                axes[x, y].legend(['G', 'H', 'S', 'R'], loc='center left', bbox_to_anchor=(1, 0.5))                
            axes[x, y].tick_params(labelrotation=45.0)
            axes[x, y].tick_params(labelright=False)
            axes[x, y].tick_params(labeltop=False)
            axes[x, y].spines['right'].set_visible(False)
            axes[x, y].spines['top'].set_visible(False)

    plt.show()

# %%
def plot_scatter(dtf: pd.DataFrame, axe, main_house: [], course: str):
    """Create and plot a scatter to compare each house with the same course"""
    # Extract each house
    _gryffindor = dtf[dtf[main_column] == 'Gryffindor'].copy()
    _hufflepuff = dtf[dtf[main_column] == 'Hufflepuff'].copy()
    _slytherin = dtf[dtf[main_column] == 'Slytherin'].copy()
    _ravenclaw = dtf[dtf[main_column] == 'Ravenclaw'].copy()
    
    _gryffindor[main_column] = _gryffindor[main_column].replace({'Gryffindor': 1} if 'Gryffindor' in main_house else {'Gryffindor': 0}).astype(int)
    _hufflepuff[main_column] = _hufflepuff[main_column].replace({'Hufflepuff': 1} if 'Hufflepuff' in main_house else {'Hufflepuff': 0}).astype(int)
    _slytherin[main_column] = _slytherin[main_column].replace({'Slytherin': 1} if 'Slytherin' in main_house else {'Slytherin': 0}).astype(int)
    _ravenclaw[main_column] = _ravenclaw[main_column].replace({'Ravenclaw': 1} if 'Ravenclaw' in main_house else {'Ravenclaw': 0}).astype(int)
    

    # Plot each house one by one to apply the associate color
    axe.scatter(_gryffindor[course], _gryffindor[main_column], s=2, color='red' if 'Gryffindor' in main_house else 'gray', alpha=0.5)
    axe.scatter(_hufflepuff[course], _hufflepuff[main_column], s=2, color='yellow' if 'Hufflepuff' in main_house else 'gray', alpha=0.5)
    axe.scatter(_slytherin[course], _slytherin[main_column], s=2, color='green' if 'Slytherin' in main_house else 'gray', alpha=0.5)
    axe.scatter(_ravenclaw[course], _ravenclaw[main_column], s=2, color='blue' if 'Ravenclaw' in main_house else 'gray', alpha=0.5)
    axe.set_yticks([0, 1])
    axe.set_xticks([dtf[course].min(), (dtf[course].min() + dtf[course].max()) // 2, dtf[course].max()])

# %% [markdown]
# For Each course, we plot a scatter by admitting that a house has the value of 1 (true) and others 0 (false).
# We can interpret that as: for a course, the grade is given {false, true} to a student member of a specific house.
# By performing a logistic regression, we want to find the probability P to be in a specific house, according to the grades.
# For P > 0.5, we assume that the student could be in the house, otherwise not.

# %%
dtf = csv_to_dataframe(path)
scatter_matrix_plot(dtf, house=[['Gryffindor'], ['Hufflepuff'], ['Slytherin'], ['Ravenclaw']], figsize=(20,5))

# %%
def create_describe_dtf(dtf: pd.DataFrame):
    """Create a dataframe with, for each student, the house, mean, std, min, max, and quartiles (based on his evaluations)"""
    max_i = dtf['Index'].max()
    nv_dtf_feat = [main_column, 'Mean', 'Std', 'Min', '25%', '50%', '75%', 'Max']
    dtf = dtf.drop(columns='Index', inplace=False)
    nv_dtf = pd.DataFrame(columns=nv_dtf_feat)
    nb_features = dtf.select_dtypes(include=['number']).columns.tolist()
    
    if main_column in nb_features:
        nb_features.remove(main_column)
        
    for i in range(0, max_i + 1):
        _selected_datas = dtf.loc[i, nb_features]
        _row = {main_column:dtf.loc[i, main_column],
        'Mean':_selected_datas.mean(),
        'Std':_selected_datas.std(), 
        'Min':_selected_datas.min(),
        '25%':_selected_datas.quantile(0.25),
        '50%':_selected_datas.quantile(0.5),
        '75%':_selected_datas.quantile(0.75),
        'Max':_selected_datas.max()}
        nv_dtf.loc[len(nv_dtf)] = _row
        
    return nv_dtf

# %%
scatter_matrix_plot(dtf, house=[['Gryffindor', 'Hufflepuff'], ['Gryffindor', 'Slytherin'], ['Gryffindor', 'Ravenclaw'], ['Hufflepuff', 'Slytherin'], ['Hufflepuff', 'Ravenclaw'], ['Slytherin', 'Ravenclaw']], figsize=(20,6))

# %%
describe_dtf = create_describe_dtf(dtf)
describe_dtf
# Out:
#      Hogwarts House         Mean           Std         Min         25%  \
# 0         Ravenclaw  4577.369508  16171.072882 -487.886086    0.715939
# 1         Slytherin  5174.310640  18652.308305 -552.060507 -113.450000
# 2         Ravenclaw  1963.374073   6543.749330 -366.076117    3.555579
# 3        Gryffindor  2630.958316   9033.045343 -537.001128   -6.497214
# 4        Gryffindor  5131.990217  17332.717316 -444.262537   -4.538438
# ...             ...          ...           ...         ...         ...
# 1595     Gryffindor  3875.311217  13565.979532 -497.235066   -4.541837
# 1596      Slytherin  4948.652307  17535.560186 -643.271092   -0.333962
# 1597     Gryffindor  5045.615270  17688.867661 -385.150457   -5.440189
# 1598     Hufflepuff  6422.781379  22926.436155 -831.741123   -4.536762
# 1599     Hufflepuff  3860.319438  13459.210475 -244.020630   -6.889120
#
#            50%         75%      Max
# 0     4.878861  272.035831  58384.0
# 1     0.091674    7.248742  67239.0
# ...

# %%
scatter_matrix_plot(describe_dtf, house=['Gryffindor', 'Hufflepuff', 'Slytherin', 'Ravenclaw'], figsize=(20,5))
