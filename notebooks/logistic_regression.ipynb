# %%
# %load_ext autoreload
# %autoreload 2
from tools.format_csv import format_csv
from tools.plot import plot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
confPath = '../../data/logistic.ini'
dataPath = '../../data/dataset_train.csv'

# %%
format_csv(dataPath)
# Out:
#       Index Hogwarts House First Name    Last Name    Birthday Best Hand  \
# 0         0      Ravenclaw     Tamara          Hsu  2000-03-30      Left
# 1         1      Slytherin      Erich      Paredes  1999-10-14     Right
# 2         2      Ravenclaw   Stephany        Braun  1999-11-03      Left
# 3         3     Gryffindor      Vesta    Mcmichael  2000-08-19      Left
# 4         4     Gryffindor     Gaston        Gibbs  1998-09-27      Left
# ...     ...            ...        ...          ...         ...       ...
# 1595   1595     Gryffindor       Jung        Blank  2001-09-14     Right
# 1596   1596      Slytherin     Shelli         Lock  1998-03-12      Left
# 1597   1597     Gryffindor   Benjamin  Christensen  1999-10-24     Right
# 1598   1598     Hufflepuff  Charlotte       Dillon  2001-09-21      Left
# 1599   1599     Hufflepuff      Kylie        Nowak  2000-08-21      Left
#
#       Arithmancy   Astronomy  Herbology  Defense Against the Dark Arts  \
# ...

# %%
format_csv(dataPath, confPath, verbose=True)
# Out:
# [INFO] Drop Index
# [INFO] Drop First Name
# [INFO] Drop Last Name
# [INFO] Drop Birthday
# [INFO] Drop Care of Magical Creatures
# [INFO] Drop Astronomy
# [INFO] Drop Arithmancy
# [INFO] replace Gryffindor by 0 in Hogwarts House
# [INFO] replace Ravenclaw by 1 in Hogwarts House
# [INFO] replace Slytherin by 2 in Hogwarts House
# [INFO] replace Hufflepuff by 3 in Hogwarts House
# [INFO] replace Left by 0 in Best Hand
# [INFO] replace Right by 1 in Best Hand
#      Hogwarts House Best Hand  Herbology  Defense Against the Dark Arts  \
# 0                 1         0   5.727180                       4.878861
# 1                 2         1  -5.987446                       5.520605
# 2                 1         0   7.725017                       3.660761
# 3                 0         0  -6.497214                      -6.977428
# 4                 0         0  -7.820623                            NaN
# ...             ...       ...        ...                            ...
# ...

# %%
df = format_csv(dataPath, confPath, norm_data=True)
df
# Out:
#      Hogwarts House Best Hand  Herbology  Defense Against the Dark Arts  \
# 0                 1         0   0.887838                   1.020284e+00
# 1                 2         1  -1.380004                   1.144605e+00
# 2                 1         0   1.274600                   7.843108e-01
# 3                 0         0  -1.478690                  -1.276549e+00
# 4                 0         0  -1.734890                  -1.075377e-17
# ...             ...       ...        ...                            ...
# 1595              0         1  -1.100148                  -6.111832e-01
# 1596              2         0   0.952475                  -6.368536e-01
# 1597              0         1  -0.841014                  -9.787505e-01
# 1598              3         0   0.445609                  -8.037361e-01
# 1599              3         0   0.828573                  -1.259441e+00
#
#       Divination  Muggle Studies  Ancient Runes  History of Magic  \
# ...

# %%
plot(df, 'Herbology', house='0', beta_0=0.1, beta_1=10)
