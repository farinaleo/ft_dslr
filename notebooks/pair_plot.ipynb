# %% [markdown]
# # Pair plot
# Pair plot is matrix of scatter and hist plots used to have a simple representation of each course with the others.
# It is a way to understand data, effects and links and identify identical courses.

# %% [markdown]
# ### Import required functions

# %%
# %load_ext autoreload
# %autoreload 2
from ft_dslr.tools import open_csv
from ft_dslr.pair_plot import pair_plot

# %%
pathTrain = '../data/external/datasets/dataset_train.csv'
pathTest = '../data/external/datasets/dataset_test.csv'

# %% [markdown]
# ### Load data

# %%
dfTest = open_csv(pathTest)
dfTrain = open_csv(pathTrain)

# %% [markdown]
# ### Plot data

# %%
pair_plot(dfTrain)

# %% [markdown]
# According to the previous exercises and the matrix, we can remove 'Arithmancy', 'Astronomy' and 'Care of Magical Creatures' from the features list used to train the model.
