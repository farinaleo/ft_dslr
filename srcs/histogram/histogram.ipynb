# %% [markdown]
# # Histogram
#
# This notebook is used to plot the histogram of the dataset. It is used to understand the distribution of the data.

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from histogram import histogram

# %% [markdown]
# ### Loading the dataset

# %%
pathTrain = '../../data/dataset_train.csv'
dfTrain = pd.read_csv(pathTrain)

# %%
def create_histogram(course):
    fig = go.Figure()
    houses = ["Ravenclaw", "Slytherin", "Gryffindor", "Hufflepuff"]
    
    for house in houses:
        house_data = dfTrain[dfTrain['Hogwarts House'] == house][course]
        fig.add_trace(go.Histogram(
            x=house_data,
            name=house,
            opacity=0.75
        ))
    
    fig.update_layout(
        title=f'Score Distribution for {course}',
        xaxis_title='Scores',
        yaxis_title='Frequency',
        barmode='overlay'
    )
    fig.show()

for course in ["Arithmancy", "Astronomy", "Herbology", "Defense Against the Dark Arts", "Divination", "Muggle Studies", "Ancient Runes", "History of Magic", "Transfiguration", "Potions", "Care of Magical Creatures", "Charms", "Flying"]:
    create_histogram(course)
# Out:
# <div>                            <div id="de2bf7fb-beae-4eec-ad5b-09d190667ef6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de2bf7fb-beae-4eec-ad5b-09d190667ef6")) {                    Plotly.newPlot(                        "de2bf7fb-beae-4eec-ad5b-09d190667ef6",                        [{"name":"Ravenclaw","opacity":0.75,"x":[58384.0,23702.0,44791.0,21630.0,15578.0,39873.0,79537.0,56259.0,71169.0,44450.0,41965.0,73385.0,59112.0,65458.0,44262.0,30461.0,null,54847.0,69442.0,46350.0,38317.0,48416.0,75206.0,57493.0,80698.0,69117.0,63085.0,99356.0,43903.0,55822.0,25521.0,22034.0,null,72259.0,65257.0,46540.0,38144.0,55003.0,null,59354.0,39228.0,41173.0,null,57532.0,55371.0,79428.0,87138.0,55527.0,61099.0,44757.0,14522.0,58984.0,26268.0,30053.0,59061.0
# ...
