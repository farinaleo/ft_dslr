# %%
# %load_ext autoreload
# %autoreload 2
from tools.format_csv import format_csv
from tools.plot import plot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
confPath = '../../data/logistic.ini'
dataPath = '../../data/dataset_train.csv'

# %%
format_csv(dataPath)
# Out:
#       Index Hogwarts House First Name    Last Name    Birthday Best Hand  \
# 0         0      Ravenclaw     Tamara          Hsu  2000-03-30      Left
# 1         1      Slytherin      Erich      Paredes  1999-10-14     Right
# 2         2      Ravenclaw   Stephany        Braun  1999-11-03      Left
# 3         3     Gryffindor      Vesta    Mcmichael  2000-08-19      Left
# 4         4     Gryffindor     Gaston        Gibbs  1998-09-27      Left
# ...     ...            ...        ...          ...         ...       ...
# 1595   1595     Gryffindor       Jung        Blank  2001-09-14     Right
# 1596   1596      Slytherin     Shelli         Lock  1998-03-12      Left
# 1597   1597     Gryffindor   Benjamin  Christensen  1999-10-24     Right
# 1598   1598     Hufflepuff  Charlotte       Dillon  2001-09-21      Left
# 1599   1599     Hufflepuff      Kylie        Nowak  2000-08-21      Left
#
#       Arithmancy   Astronomy  Herbology  Defense Against the Dark Arts  \
# ...

# %%
format_csv(dataPath, confPath)
# Out:
#      Hogwarts House  Arithmancy   Astronomy  Herbology  \
# 0         Ravenclaw     58384.0 -487.886086   5.727180
# 1         Slytherin     67239.0 -552.060507  -5.987446
# 2         Ravenclaw     23702.0 -366.076117   7.725017
# 3        Gryffindor     32667.0  697.742809  -6.497214
# 4        Gryffindor     60158.0  436.775204  -7.820623
# ...             ...         ...         ...        ...
# 1595     Gryffindor     49009.0  354.280086  -4.541837
# 1596      Slytherin     63296.0  367.531174   6.061064
# 1597     Gryffindor     63905.0  544.018925  -3.203269
# 1598     Hufflepuff     82713.0  453.676219   3.442831
# 1599     Hufflepuff     48639.0  688.911989   5.421046
#
#       Defense Against the Dark Arts  Divination  Muggle Studies  \
# 0                          4.878861       4.722      272.035831
# 1                          5.520605      -5.612     -487.340557
# 2                          3.660761       6.140      664.893521
# ...

# %%
df = format_csv(dataPath, confPath, norm_data=True)
df
# Out:
#      Hogwarts House  Arithmancy  Astronomy  Herbology  \
# 0         Ravenclaw    0.524552  -1.014194   0.878628
# 1         Slytherin    1.055434  -1.137535  -1.365690
# 2         Ravenclaw   -1.554729  -0.780078   1.261379
# 3        Gryffindor   -1.017252   1.264555  -1.463352
# 4        Gryffindor    0.630908   0.762982  -1.716894
# ...             ...         ...        ...        ...
# 1595     Gryffindor   -0.037505   0.604428  -1.088736
# 1596      Slytherin    0.819040   0.629896   0.942595
# 1597     Gryffindor    0.855551   0.969101  -0.832290
# 1598     Hufflepuff    1.983142   0.795465   0.440987
# 1599     Hufflepuff   -0.059687   1.247582   0.819978
#
#       Defense Against the Dark Arts  Divination  Muggle Studies  \
# 0                          1.010346    0.377371        1.021139
# 1                          1.133455   -2.109573       -0.540256
# 2                          0.776671    0.718622        1.828915
# ...

# %%
plot(df, 'Astronomy', beta_0=0.1, beta_1=10)
