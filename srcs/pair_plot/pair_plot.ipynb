# %%
# %load_ext autoreload
# %autoreload 2
from tools import open_csv
from pair_plot import pair_plot

# %%
pathTrain = '../../data/dataset_train.csv'
pathTest = '../../data/dataset_test.csv'

# %%
dfTest = open_csv(pathTest)
dfTrain = open_csv(pathTrain)

# %%
pair_plot(dfTrain)
